# %% [markdown]
# #### Data Understanding
#
# Car_Name : Name of the cars
#
# Year : Year of the car when it was bought
#
# Selling_Price : Price at which the car is being sold
#
# Present_Price : The current ex-showroom price of the car
#
# Kms_Driven : Number of Kilometres the car is driven
#
# Fuel_Type : Fuel type of car (petrol / diesel / CNG / LPG / electric)
#
# Seller_Type : Tells if a Seller is Individual or a Dealer
#
# Transmission : Gear transmission of the car (Automatic/Manual)
#
# Owner : Number of previous owners of the car

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read and Analys Data

# %%
df = pd.read_csv('car data.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
# show unique value
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
print(df['Fuel_Type'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]
# ['Petrol' 'Diesel' 'CNG']

# %%
# check missing or null value
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %% [markdown]
# ## Categorical Data Analysis¶

# %%
def bar_plot(variable):
    global n
    var = df[variable] 
    var_value = var.value_counts() 
    
    plt.figure(figsize = (6,3)) 
    plt.bar(var_value.index, var_value)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    
category = ["Car_Name", "Fuel_Type", "Seller_Type", "Transmission"] 
for i in category:
    bar_plot(i)

# %% [markdown]
# Result:
# 1. Car_name we don't use it, we will drop it
# 2. Petrol is the most fuel_type used
# 3. sellers from dealers are more numerous than individuals
# 4. manual transmission sells more than automatic

# %% [markdown]
# ## Numerical Data Analysis

# %%
def plot_hist(variable):
    plt.figure(figsize=(6,3))
    plt.hist(df[variable], bins = 30)
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title(f"Graphic of {variable}")
    plt.show()

numeric = ["Year", "Selling_Price", "Present_Price", "Kms_Driven", "Owner"] 
for i in numeric:
    plot_hist(i)

# %% [markdown]
# ##### Result:
# 1. sales increased every year, the most in 2016
# 2. most selling price and present price are in the price range of 0 - 20
# 3. most kms sold are in the range of 0 - 10,000

# %% [markdown]
# ## Categorical Visualization

# %%
import seaborn as sns

# %%
fig = sns.FacetGrid(df, col = "Fuel_Type")
fig.map(sns.distplot, "Selling_Price")
plt.show()
# Out:
# d:\anaconda3\envs\carprediction\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# d:\anaconda3\envs\carprediction\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# comparison Seller_Type vs Selling_Price
fig = sns.FacetGrid(df, col = "Seller_Type")
fig.map(sns.distplot, "Selling_Price")
plt.show()
# Out:
# d:\anaconda3\envs\carprediction\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# d:\anaconda3\envs\carprediction\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# comparison Transmission vs Selling_Price
fig = sns.FacetGrid(df, col = "Transmission")
fig.map(sns.distplot, "Selling_Price")
plt.show()
# Out:
# d:\anaconda3\envs\carprediction\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# d:\anaconda3\envs\carprediction\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ## Outlier Data Analysis

# %%
list_features = ["Selling_Price", "Present_Price"] 
sns.boxplot(data = df.loc[:, list_features], orient = "v", palette = "Set1") 
plt.show()  
# Result : Both Selling_Price and Present_Price variables have outlier data

# %%
list_features = ["Year", "Kms_Driven", "Owner"] 
sns.boxplot(data = df.loc[:, list_features], orient = "v", palette = "Set1") 
plt.show()  
# Result: Kms_Driven has outlier data

# %% [markdown]
# we can remove outliers but in this condition we do not remove them, because the outliers are few and do not affect the model.

# %% [markdown]
# ## Data Cleaning

# %%
# drop car_name because it is useless
final_dataset = df.drop(['Car_Name'], axis=1)
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_dataset['Age'] = 2023 - df['Year']
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Age
# 0       Manual      0    9
# 1       Manual      0   10
# 2       Manual      0    6
# 3       Manual      0   12
# 4       Manual      0    9

# %%
# Drop Year because we have actual age
final_dataset.drop(['Year'], axis=1, inplace=True)
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Age
# 0       Manual      0    9
# 1       Manual      0   10
# 2       Manual      0    6
# 3       Manual      0   12
# 4       Manual      0    9

# %%
# Drop Owner because Owner has bad correlation 
# See heatmap corr
final_dataset.drop(['Owner'], axis=1, inplace=True)
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Age
# 0       Manual    9
# 1       Manual   10
# 2       Manual    6
# 3       Manual   12
# 4       Manual    9

# %%
# one hot encoding
final_dataset = pd.get_dummies(final_dataset, drop_first=True)
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Age  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000    9             False
# 1           4.75           9.54       43000   10              True
# 2           7.25           9.85        6900    6             False
# 3           2.85           4.15        5200   12             False
# 4           4.60           6.87       42450    9              True
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0              True                   False                 True
# 1             False                   False                 True
# 2              True                   False                 True
# 3              True                   False                 True
# 4             False                   False                 True

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven       Age  \
# Selling_Price                1.000000       0.878983    0.029187 -0.236141
# Present_Price                0.878983       1.000000    0.203647  0.047584
# Kms_Driven                   0.029187       0.203647    1.000000  0.524342
# Age                         -0.236141       0.047584    0.524342  1.000000
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.064315
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.059959
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.039896
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.000394
#
#                         Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price                   0.552339         -0.540571
# Present_Price                   0.473306         -0.465244
# Kms_Driven                      0.172515         -0.172874
# ...

# %%
sns.pairplot(final_dataset)

# %%
# heatmap corr
corrmat = final_dataset.corr()
corr_features = corrmat.index
plt.figure(figsize=(15,10))
# plot heatmap
corr_map = sns.heatmap(final_dataset[corr_features].corr(), annot=True, cmap="RdYlGn")

# %%
# Independent and dependent features
X = final_dataset.iloc[:,1:]
y = final_dataset.iloc[:,0]

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Age  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0           5.59       27000    9             False              True
# 1           9.54       43000   10              True             False
# 2           9.85        6900    6             False              True
# 3           4.15        5200   12             False              True
# 4           6.87       42450    9              True             False
#
#    Seller_Type_Individual  Transmission_Manual
# 0                   False                 True
# 1                   False                 True
# 2                   False                 True
# 3                   False                 True
# 4                   False                 True

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
# Feature importance
from sklearn.ensemble import ExtraTreesRegressor
model =  ExtraTreesRegressor()
model.fit(X, y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.3829021  0.04018969 0.07804414 0.21353337 0.01018459 0.1406161
#  0.13453001]

# %%
# Plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
colors = ['red', 'green', 'blue', 'yellow', 'purple']
feat_importances.nlargest(5).plot(kind='barh', color=colors)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (240, 7)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random = RandomForestRegressor()

# %%
# Hyperparameters Tuning
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start=100, stop=1200, num=12)]

# Number of features to consider at every split
max_features = ['sqrt', 'log2']  # Ganti 'auto' dengan 'sqrt' atau 'log2'

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num=6)]

# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# Method of selecting samples for training each tree
# bootstrap = [True, False]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf
}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['sqrt', 'log2'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune

rf = RandomForestRegressor()

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations

rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.1s
# ...

# %% [markdown]
# ## Model Evaluation

# %%
prediction = rf_random.predict(X_test)
prediction
# Out:
# array([ 7.07895458,  0.54725578,  4.96987322,  8.75017144, 17.2315625 ,
#         5.26789213,  3.35806418,  0.77304343,  4.57833071,  4.56612969,
#         2.84090509,  0.8854044 ,  5.08222804,  7.85947965,  7.87411436,
#        11.94858698,  7.2226237 ,  4.10654418,  0.45692227,  1.45078475,
#         3.91019761,  5.20111815,  5.60875848,  9.1037526 ,  0.23347849,
#         0.7701108 ,  0.37270433,  0.60256083,  0.50217569,  4.75700632,
#         5.03876693,  5.80236222,  0.48801373,  8.17143403,  3.60025402,
#         1.23193179,  5.61654734,  6.81899249,  0.30495648,  8.62345598,
#        10.567475  , 20.83685937,  4.97163526,  4.45569408,  5.49410662,
#        11.64416838,  0.30691609,  0.89253923,  5.28136363,  7.49849943,
#         7.37221761,  3.47506053,  4.9473327 , 22.572825  ,  1.11515148,
#         1.05108866,  0.59615524,  2.60466844,  3.57220634,  1.60441263,
#         3.88792349])

# %%
sns.distplot(y_test-prediction)
# Out:
# C:\Users\hudza\AppData\Local\Temp\ipykernel_1384\1520944062.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-prediction)
# <Axes: xlabel='Selling_Price', ylabel='Density'>

# %%
plt.scatter(y_test, prediction)

# %%
# Create a scatter plot for X_test vs. Selling_Price (Actual and Predicted)
plt.figure(figsize=(10, 6))
plt.scatter(X_test['Present_Price'], y_test, alpha=0.5, label='Actual', c='blue')
plt.scatter(X_test['Present_Price'], prediction, alpha=0.5, label='Predicted', c='red')
plt.xlabel("Present_Price")
plt.ylabel("Selling_Price")
plt.title("Scatter Plot of Present_Price vs. Selling Price (Actual vs. Predicted)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Regression Evaluation Metrics

# %%
from sklearn import metrics

# %%
#Evaluating the Model
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 0.5770163625933177
# MSE: 1.4660581601887865
# RMSE: 1.2108088867318354

# %% [markdown]
# ## Compare model vs actual data

# %%
compare = pd.DataFrame({'Actual': y_test.values, 'Predict': prediction})

print(compare[:10])
# Out:
#    Actual    Predict
# 0    8.25   7.078955
# 1    0.50   0.547256
# 2    5.25   4.969873
# 3    9.50   8.750171
# 4   18.00  17.231562
# 5    5.50   5.267892
# 6    3.75   3.358064
# 7    0.45   0.773043
# 8    4.50   4.578331
# 9    4.50   4.566130

# %% [markdown]
# the prediction of the model built has a minimum error seen from the evaluation matrix. the results of the model can be seen by comparing the actual data, where the predicted results are close to the actual price.

# %%
# Deployment 
import pickle
# open file, where you ant to store teh data
file = open('random_forest_regression_model.pkl', 'wb')

# dumo information to that file
pickle.dump(rf_random, file)
